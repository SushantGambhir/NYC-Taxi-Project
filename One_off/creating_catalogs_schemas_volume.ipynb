# %%
# Creating the catalog
# Please update the managed location path
spark.sql("create catalog if not exists nyctaxi")

# For real cloud enviornment, it will not work. 
# We have to give this instead
# spark.sql("create catalog if not exists nyctaxi managed location 'your path here'")
# How to get path?: Catalog -> Settings -> External location -> Click on it and get the URL
